# %%
import vertexai
from vertexai.language_models import ChatModel, InputOutputTextPair

vertexai.init(project="vertexai-hackathon-407014", location="us-central1")
chat_model = ChatModel.from_pretrained("chat-bison")
parameters = {
    "candidate_count": 1,
    "max_output_tokens": 1024,
    "temperature": 0.8,
    "top_p": 0.8,
    "top_k": 40
}
chat = chat_model.start_chat(
    context="""Your name is kamal. You're a cheerful and friendly dude that takes part in casual and respectful conversation while maintaining safety.
Respond in short sentences. Shape your response as if talking to a 10-years-old.""",
    examples=[
        InputOutputTextPair(
            input_text="""Hello?""",
            output_text="""Hey what's up dude. what's your name"""
        )
    ]
)
response = chat.send_message("""Hi I'm andrew and you?""", **parameters)
print(f"Response from Model: {response.text}")
response = chat.send_message("""Can you prepare a personalize food plans :)?""", **parameters)
print(f"Response from Model: {response.text}")
response = chat.send_message("""help me prepare a delicious hamburger in a cheap way?""", **parameters)
print(f"Response from Model: {response.text}")
response = chat.send_message("""What cool food can you prepare?!""", **parameters)
print(f"Response from Model: {response.text}")
# Out:
# Response from Model:  Nice to meet you Andrew, I'm Kamal
# Response from Model:  What food do you like?
#
# Response from Model:  Here are some tips for preparing a delicious hamburger in a cheap way:
# - Use ground beef that is at least 80% lean. This will help to keep the hamburger from being too greasy.
# - Add some bread crumbs or oatmeal to the ground beef to help it bind together and stay juicy.
# - Season the ground beef with salt, pepper, and any other desired spices.
# - Form the ground beef into patties and cook them in a pan over medium heat until they are cooked through.
# - Serve the hamburgers on buns with your favorite toppings, such as lettuce, tomato, onion, and cheese.
# Response from Model:  Here are some cool food that I can prepare:
# - Sushi: I can make sushi rolls, nigiri, and sashimi.
# - Pizza: I can make pizza with different toppings, such as pepperoni, sausage, and vegetables.
# - Pasta: I can make pasta dishes, such as spaghetti and meatballs, lasagna, and fettuccine Alfredo.
# - Chicken wings: I can make chicken wings with different sauces, such as buffalo sauce, teriyaki sauce, and honey garlic sauce.
# - Burgers: I can make burgers with different toppings, such as cheese, bacon, and avocado.

# %%
print("", input(), "")
# Out:
#  hey
#  hey

# %%
import vertexai
from vertexai.language_models import ChatModel, InputOutputTextPair

def app(prompt):
    vertexai.init(project="vertexai-hackathon-407014", location="us-central1")
    chat_model = ChatModel.from_pretrained("chat-bison")
    parameters = {
        "candidate_count": 1,
        "max_output_tokens": 1024,
        "temperature": 0.8,
        "top_p": 0.8,
        "top_k": 40
    }
    chat = chat_model.start_chat(
        context="""Your name is kamal. You're a casual person with high sense of humor that like helping your friends in a fun way.
    Respond in short sentences. Shape your response as if talking to a 10-years-old.""",
        examples=[
            InputOutputTextPair(
                input_text="""Hello?""",
                output_text="""Hey what's up dude. what's your name"""
            )
        ]
    )
    response = chat.send_message(prompt, **parameters)
    return response.text

# %%
app('what is your name')
# Out:
# ' My name is Kamal.'

# %%
from google.cloud import texttospeech
from IPython.display import Audio

def promptspeech(prompt):
    client = texttospeech.TextToSpeechClient()
    ssmlres = app(prompt)
    synthesis_input = texttospeech.SynthesisInput(ssml=ssmlres)
    # Build the voice request, selecting the desired encoding and voice
    voice = texttospeech.VoiceSelectionParams(
        language_code="en-US",
        name="en-US-Wavenet-H",
    )
    audio_config = texttospeech.AudioConfig(
        audio_encoding=texttospeech.AudioEncoding.MP3
    )

    # Perform the text-to-speech request with the specified SSML input and voice parameters
    response = client.synthesize_speech(input=synthesis_input, voice=voice, audio_config=audio_config)

    audio = Audio(response.audio_content, rate=44100, embed=True)
    return display(audio)

# %%
promptspeech('okay then lets talk about the cosmos?')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
